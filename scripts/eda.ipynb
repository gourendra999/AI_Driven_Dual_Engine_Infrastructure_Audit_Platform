# %%
import pandas as pd

# %%
df1 = pd.read_csv("assests/Allocated Limit for Honble MPs.csv")
df1.columns = df1.columns.str.strip().str.title()

# %%
df1.head()
# Out:
#   Sr. No.              State  Hon'Ble Members Of Parliaments   Constituency  \
# 0       1        Maharashtra  AASHTIKAR PATIL NAGESH BAPURAO        HINGOLI
# 1       2  Jammu And Kashmir             ABDUL RASHID SHEIKH     BARAMULLAH
# 2       3              Bihar               ABHAY KUMAR SINHA  AURANGABAD_BR
# 3       4        West Bengal            ABHIJIT GANGOPADHYAY         TAMLUK
# 4       5        West Bengal                  Abu Taher Khan    MURSHIDABAD
#
#   Allocated Amount ( ₹ )
# 0              190289442
# 1           154773472.11
# 2              147000000
# 3              147000000
# 4              147000000

# %%
df2 = pd.read_csv("assests/Amount consented for Calamity.csv")
df2.columns = df2.columns.str.strip().str.title()
df2.head()
# Out:
#   Sr. No.      Calamity Type  \
# 0       1  National Calamity
# 1       2  National Calamity
# 2       3  National Calamity
# 3       4  National Calamity
# 4       5  National Calamity
#
#                                        Calamity Name  \
# 0                               Flood 2025 in Punjab
# 1                               Flood 2025 in Punjab
# 2                               Flood 2025 in Punjab
# 3  Andhra Pradesh rainfall and consequent floods ...
# 4                            Meppadi landslides 2024
#
#   Hon'Ble Members Of Parliament Date Of Consent Consent Amount ( ₹ )
# 0      Shri Gurjeet Singh Aujla     07-Dec-2025              7067400
# 1      GURMEET SINGH MEET HAYER     03-Nov-2025              7500000
# 2                Shri Jual Oram     10-Oct-2025             10000000
# 3        Krishna Prasad Tenneti     26-Mar-2025              1000000
# 4                SHAFI PARAMBIL     02-Mar-2025              2500000

# %%
df3 = pd.read_csv("assests/Works Recommended.csv")
df3.columns = df3.columns.str.strip().str.title()
df3['Recommended Date'] = pd.to_datetime(df3['Recommended Date'], errors='coerce')
df3.head()
# Out:
# C:\Users\goure\AppData\Local\Temp\ipykernel_18392\2459610875.py:1: DtypeWarning: Columns (0: Sr. No., 1: RECOMMENDED AMOUNT   ( ₹ )) have mixed types. Specify dtype option on import or set low_memory=False.
#   df3 = pd.read_csv("assests/Works Recommended.csv")
#   Sr. No.      Work Category  \
# 0       1      Normal/Others
# 1       2  Trust and Society
# 2       3  Trust and Society
# 3       4      Normal/Others
# 4       5      Normal/Others
#
#                                                 Work      State  \
# 0  WS/\t MP620/2024-2025/133166-Construction of b...  Karnataka
# 1  WS/\t MP620/2025-2026/133167-Construction of r...  Karnataka
# 2  WS/\t MP620/2024-2025/133190-Construction of b...  Karnataka
# 3  WS/\t MP620/2025-2026/133191-Construction of b...  Karnataka
# 4  WS/\t MP620/2024-2025/133301-Construction of b...  Karnataka
#
#                                         Ida Hon'Ble Members Of Parliament  \
# ...

# %%
df4 = pd.read_csv("assests/Works Sanctioned.csv")
df4.columns = df4.columns.str.strip().str.title()
df4.head()
# Out:
# C:\Users\goure\AppData\Local\Temp\ipykernel_18392\1768302708.py:1: DtypeWarning: Columns (0: Sr. No., 1: Sanction Amount ( ₹ )) have mixed types. Specify dtype option on import or set low_memory=False.
#   df4 = pd.read_csv("assests/Works Sanctioned.csv")
#   Sr. No.      Work Category  \
# 0       1      Normal/Others
# 1       2  Trust and Society
# 2       3  Trust and Society
# 3       4      Normal/Others
# 4       5      Normal/Others
#
#                                                 Work      State  \
# 0  WS/\t MP620/2024-2025/133166-Construction of b...  Karnataka
# 1  WS/\t MP620/2025-2026/133167-Construction of r...  Karnataka
# 2  WS/\t MP620/2024-2025/133190-Construction of b...  Karnataka
# 3  WS/\t MP620/2025-2026/133191-Construction of b...  Karnataka
# 4  WS/\t MP620/2024-2025/133301-Construction of b...  Karnataka
#
#                                         Ida Hon'Ble Members Of Parliament  \
# ...

# %%
df5 = pd.read_csv("assests/Works Completed.csv")
df5.columns = df5.columns.str.strip().str.title()
df5.head()
# Out:
#   Sr. No.  Work Category                                               Work  \
# 0       1  Normal/Others  WS/MP418/2024-2025/133409-Construction of road...
# 1       2  Normal/Others  WS/MP18152/2024-2025/133691-Construction of ro...
# 2       3  Normal/Others  WS/MP345/2024-2025/134140-Construction of road...
# 3       4  Normal/Others  WS/MP18152/2024-2025/133686-Construction of ro...
# 4       5  Normal/Others  WS/MP18152/2024-2025/133690-Construction of ro...
#
#     State                                           Ida  \
# 0   Bihar  ARARIA(DISTRICT PLANNING OFFICER ARARIA_IDA)
# 1  Punjab    FARIDKOT(DEPUTY COMMISSIONER FARIDKOT_IDA)
# 2  Kerala         KOLLAM(DISTRICT COLLECTOR KOLLAM_IDA)
# 3  Punjab    FARIDKOT(DEPUTY COMMISSIONER FARIDKOT_IDA)
# 4  Punjab    FARIDKOT(DEPUTY COMMISSIONER FARIDKOT_IDA)
#
#                                     Work Description  \
# 0  PCC Road from Permeshwar Bhagat house to Ramde...
# 1  Construction of MID DAY Meal Shed in Govt Prim...
# ...

# %%
df6 = pd.read_csv("assests/Expenditure on Completed and On-going Works as on Date.csv")
df6.columns = df6.columns.str.strip().str.title()
df6['Work'] = df6['Work Id'] + '-' + df6['Work']
df6.head()
# Out:
# C:\Users\goure\AppData\Local\Temp\ipykernel_18392\3729604758.py:1: DtypeWarning: Columns (0: Sr. No., 1: Fund Disbursed Amount ( ₹ )) have mixed types. Specify dtype option on import or set low_memory=False.
#   df6 = pd.read_csv("assests/Expenditure on Completed and On-going Works as on Date.csv")
#   Sr. No.          State                                               Work  \
# 0       1  Uttar Pradesh  WS/MP18218/2025-2026/233777-Construction of ro...
# 1       2  Uttar Pradesh  WS/MP18218/2025-2026/233878-Construction of ro...
# 2       3  Uttar Pradesh  WS/MP18218/2025-2026/233781-Construction of ro...
# 3       4         Odisha  WS/MP370/2024-2025/145537-Construction of comm...
# 4       5      Karnataka  WS/MP18082/2025-2026/242466-Construction of ad...
#
#                        Work Id  \
# 0  WS/MP18218/2025-2026/233777
# 1  WS/MP18218/2025-2026/233878
# 2  WS/MP18218/2025-2026/233781
# 3    WS/MP370/2024-2025/145537
# 4  WS/MP18082/2025-2026/242466
#
# ...

# %%
pd.set_option('display.max_columns', None)
master_df = pd.read_csv("assests/mplads_master_analytics_ready.csv")
master_df.head(5)
# Out:
# C:\Users\goure\AppData\Local\Temp\ipykernel_18392\1806726466.py:2: DtypeWarning: Columns (0: Sr. No., 1: Sr. No._sanctioned) have mixed types. Specify dtype option on import or set low_memory=False.
#   master_df = pd.read_csv("assests/mplads_master_analytics_ready.csv")
#   Sr. No.      Work Category  \
# 0       1      NORMAL/OTHERS
# 1       2  TRUST AND SOCIETY
# 2       3  TRUST AND SOCIETY
# 3       4      NORMAL/OTHERS
# 4       5      NORMAL/OTHERS
#
#                                                 Work      State  \
# 0  WS/\t MP620/2024-2025/133166-CONSTRUCTION OF B...  KARNATAKA
# 1  WS/\t MP620/2025-2026/133167-CONSTRUCTION OF R...  KARNATAKA
# 2  WS/\t MP620/2024-2025/133190-CONSTRUCTION OF B...  KARNATAKA
# 3  WS/\t MP620/2025-2026/133191-CONSTRUCTION OF B...  KARNATAKA
# 4  WS/\t MP620/2024-2025/133301-CONSTRUCTION OF B...  KARNATAKA
#
#                                         Ida Hon'Ble Members Of Parliament  \
# ...

# %%
master_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 107090 entries, 0 to 107089
# Data columns (total 40 columns):
#  #   Column                                    Non-Null Count   Dtype
# ---  ------                                    --------------   -----
#  0   Sr. No.                                   107090 non-null  object
#  1   Work Category                             107089 non-null  str
#  2   Work                                      107089 non-null  str
#  3   State                                     107089 non-null  str
#  4   Ida                                       107090 non-null  str
#  5   Hon'Ble Members Of Parliament             107089 non-null  str
#  6   Constituency                              107089 non-null  str
#  7   Work Description                          106974 non-null  str
#  8   Recommended Date                          107089 non-null  str
#  9   Recommended Amount   ( ₹ )                107090 non-null  float64
# ...
